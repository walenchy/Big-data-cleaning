# %% [markdown]
# # web scraping using Beautiful Soup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#magic line

# %% [markdown]
# to perform web scraping,you should also import the libraries shown below.
# The urlib. request module is used to open URLs.
# The beuatiful soup package is used to extract data from html files.
# The beautiful soup library's name is bs4 which stands for Beautiful Soup, version 4.
# URL - Universal Resource Locator
# ESC + M - change to Markdown Esc Y

# %% [markdown]
# how to check libraries install using anaconda prompt - pip freeze or conda list

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %% [markdown]
# #After importing neccessary modules, you should specify the URL containing the data set and pass it to the urlopen() to
# get the html of the page.

# %%
url = "http://www.hubertiming.com/results/2017GPTR10K"
html = urlopen(url) #keep the website open

# %% [markdown]
# # step 2

# %% [markdown]
# Step 3 - Getting the html of the page is just the  fist step
# Next step is to create a Beautiful soup object from the html.This is done by passing the html to the beautiful soup() function. the beautiful soup package is used to parse the html, that is , take the raw html text and break it  into  python
# objects.The second argument 'lxml' is the parser whose details you do not need to worry about at this point.

# %% [markdown]
# conda install -c conda-forge jupyter_contrib_nbextensions

# %%
html

# %% [markdown]
# # step- gettting the html of the page is just the first step

# %% [markdown]
# # step- gettting the html of the page is just the first step
# Next step is to create a beautiful soup onject fro html.Thisis done by passing the html to the Beautifulsoup() function. The Beautiful soup package is used to parse the html,that is, take the raw html text and break it into python objects. The second argument 'lxml' is the html parser whose details you do not need to worry about at this point.

# %%
#ggggggggggggggggg
soup = BeautifulSoup(html, 'lxml')# so create an object call soup
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta content="Race results for the 2017 Intel Great Place to Run \ Urban Clash Games!" property="og:title"/>
# <meta content="Results of the 2017 Intel Great Place to Run \ Urban Clash Games at Hillsboro Stadium in Hillsboro, OR" property="og:description"/>
# <meta content="https://www.hubertiming.com/results/2017GPTRForResults.jpg" property="og:image"/>
# <meta content="https://www.hubertiming.com/results/2017GPTR10K" property="og:url"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <title>Race results for the 2017 Intel Great Place to Run \ Urban Clash Games!</title>
# <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.2.1/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="https://use.fontawesome.com/releases/v5.13.0/css/all.css" rel="stylesheet"/>
# ...

# %%
#The soup object allows you to extract interesting information about the website you are scrapping such as getting the 
#title of the page as shown below.

#get the title
title = soup.title
print (title)
# Out:
# <title>Race results for the 2017 Intel Great Place to Run \ Urban Clash Games!</title>

# %% [markdown]
# #you can also get the text of the webpage and quickly print it out to check if what you expect.

# %%
#print out the text
text = soup.get_text()
print(soup.text)
# Out:
# Race results for the 2017 Intel Great Place to Run \ Urban Clash Games!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  2017 Intel Great Place to Run 10K \ Urban Clash Games
#  Hillsboro Stadium, Hillsboro, OR
#  June 2nd, 2017
#
#
#
#
#
#
#
#
#  Email
#                         timing@hubertiming.com with results questions. Please include your bib number if you have it.
#
#
#
#
#
#
#
#
#
# Huber Timing Home
#
#
#
#
#
# 10K:
#
#
# Finishers:
# 577
#
#
# Male:
# 414
#
#
# Female:
# 163
#
#
#
#
#
#
#
#
#
#  5K Individual
#  5K Team
#  10K Individual
#  10K Team
#  Summary
#
#
#
#
# Indvidual Results
#
#
#
# 10K Results
#
#
#
# Search:
#
# Search
# Division:
#
# Men
# Women
# Masters Men
# Masters Women
#
# F 18-25
# F 26-35
# F 36-45
# F 46-55
# F Under 18
# M 18-25
# M 26-35
# M 36-45
# M 46-55
# M 55+
# M Under 18
#  Team:
#
# Unattached
# COLUMBIA TEAM A
# COLUMBIA TEAM B
# COLUMBIA TEAM C
# COLUMBIA TEAM D
# COLUMBIA TEAM E
# DTNA1
# DTNA2
# DTNA3
# FXG1
# INTEL TEAM A
# INTEL TEAM B
# ...

# %% [markdown]
# you can view the html of the webpage by right- clicking antwhere on the webpage and selecting "inspect".this is what the result looks like
# CTRL SHIFT i- SHOT CUT FOR INSPECT ELEMENT
#
#  you can use the find_all() method of soup to extract useful html tags within a webpage.Example of useful tags include <a> for hyperlinks, <table> for tables, <tr> for rows, <th> for table headers, and <td> for table cells.The code below shows how to extract all the hyperlinks within the webpage.

# %%
soup.find_all('a')
# Out:
# [<a href="mailto:timing@hubertiming.com">timing@hubertiming.com</a>,
#  <a href="https://www.hubertiming.com/">Huber Timing Home</a>,
#  <a class="btn btn-primary btn-lg" href="/results/2017GPTR" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-user"></i> 5K Individual</a>,
#  <a class="btn btn-primary btn-lg" href="/results/team/2017GPTR" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-users"></i> 5K Team</a>,
#  <a class="btn btn-primary btn-lg" href="/results/team/2017GPTR10K" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-users"></i> 10K Team</a>,
#  <a class="btn btn-primary btn-lg" href="/results/summary/2017GPTR10K" role="button" style="margin: 0px 0px 5px 5px"><i class="fa fa-stream"></i> Summary</a>,
#  <a id="individual" name="individual"></a>,
#  <a data-url="/results/2017GPTR10K" href="#tabs-1" id="rootTab" style="font-size: 18px">10K Results</a>,
# ...

# %% [markdown]
# provide additional information about html elements.you can use a for loop and the get("href") method to extract and print out only hyperlinks.

# %%
all_links = soup.find_all('a')# find me all the hyper ref links 
for link in all_links:#simply means go through all the links
    print(link.get("href"))#then print them
# Out:
# mailto:timing@hubertiming.com
# https://www.hubertiming.com/
# /results/2017GPTR
# /results/team/2017GPTR
# /results/team/2017GPTR10K
# /results/summary/2017GPTR10K
# None
# #tabs-1
# https://www.hubertiming.com/
# https://facebook.com/hubertiming/
# None

# %% [markdown]
# To print out table rows only, pass the "tr" arqument in soup.find_all()

# %% [markdown]
# # dont forget our job is to take  a from a webpage and convert it into  a dataframe for easier manipulation using python.To get there, you should get all table rows in list form and then convert the list into dataframe.Below is a for loop that iterates through table rows and print out the cells of the rows.

# %%
rows = soup.find_all('tr')#print the first 10 rows for sanity check
print(rows[:10])
# Out:
# [<tr colspan="2">
# <b>10K:</b>
# </tr>, <tr>
# <td>Finishers:</td>
# <td>577</td>
# </tr>, <tr>
# <td>Male:</td>
# <td>414</td>
# </tr>, <tr>
# <td>Female:</td>
# <td>163</td>
# </tr>, <tr class="header">
# <th>Place</th>
# <th>Bib</th>
# <th>Name</th>
# <th>Gender</th>
# <th>City</th>
# <th>State</th>
# <th>Chip Time</th>
# <th>Chip Pace</th>
# <th>Gun Time</th>
# <th>Team</th>
# </tr>, <tr data-bib="814">
# <td>1</td>
# <td>814</td>
# <td>
#
#                     JARED WILSON
#
#                 </td>
# <td>M</td>
# <td>TIGARD</td>
# <td>OR</td>
# <td>36:21</td>
# <td>5:51</td>
# <td>36:24</td>
# <td></td>
# </tr>, <tr data-bib="573">
# <td>2</td>
# <td>573</td>
# <td>
#
#                     NATHAN A SUSTERSIC
#
#                 </td>
# <td>M</td>
# <td>PORTLAND</td>
# <td>OR</td>
# <td>36:42</td>
# <td>5:55</td>
# <td>36:45</td>
# <td>
# <img class="lazy teamThumbs" data-src="/teamLogoThumbnail/logo?teamName=INTEL%20TEAM%20F&amp;raceId=1251&amp;state=OR"/>
# ...

# %%
for row in rows:
    row_td = row.find_all('td')
print(row_td)
type(row_td)
# Out:
# [<td>577</td>, <td>443</td>, <td>
#
#                     LIBBY B MITCHELL
#
#                 </td>, <td>F</td>, <td>HILLSBORO</td>, <td>OR</td>, <td>1:41:18</td>, <td>16:20</td>, <td>1:42:10</td>, <td></td>]
# bs4.element.ResultSet

# %% [markdown]
# The output above  shows  that each row is printed with html tags embedded in each row.This is not whhat you want.you can remove the html tags using Beuatiful soup.
# The easiest way to remove html tags is to use Beautiful Soup, and it takes just one line of code to do this.pass the string of interest into Beautifulsoup() and use the get_text()method to extract the text without html tags

# %%
str_cells =str(row_td)
str_cells
# Out:
# '[<td>577</td>, <td>443</td>, <td>\r\n\r\n                    LIBBY B MITCHELL\r\n\r\n                </td>, <td>F</td>, <td>HILLSBORO</td>, <td>OR</td>, <td>1:41:18</td>, <td>16:20</td>, <td>1:42:10</td>, <td></td>]'

# %%
cleantext = BeautifulSoup(str_cells, "lxml").get_text()
print(cleantext)
# Out:
# [577, 443,
#
#                     LIBBY B MITCHELL
#
#                 , F, HILLSBORO, OR, 1:41:18, 16:20, 1:42:10, ]

# %% [markdown]
# #using regular expreswion is highly discouraged since it requires several lines of code and one can easily make mistakes.it requires importing the re(for regular expressions)module. the code below shows how to build a regular expression that finds all the characters inside the <td> html tags and replace them with an empty string to match the re.compile().The dot, star, and question mark(.*?)will match an opening angle bracket followed by anything and followed by  aclosing angle  brackect.
# it matches text in a non _ greedy fashion, that is, it matches the shotest possible string. if you ommit the question mark, it will match all the text between the first opening angle bracket and the last closing angle bracket.After compiling a regular expression, you can use the re, sub() method to find all the substrings where the regular expression matches and replace them with an empty string.The full code below generates an empty list,extract in between html tags for each row,and append it to the assigned list.

# %%
import re

list_rows = []#generates an emty list
for row in rows:
    cells = row.find_all('td')#find all td
    str_cells = str(cells)#then pass it to str function
    clean = re.compile('<.*?>')
    clean2 = (re.sub(clean, '',str_cells))
    list_rows.append(clean2)
print(clean2)
type(clean2)
# Out:
# [577, 443,
#
#                     LIBBY B MITCHELL
#
#                 , F, HILLSBORO, OR, 1:41:18, 16:20, 1:42:10, ]
# str

# %% [markdown]
# The next step is to convert the list into a dataframe and get a quick view of the first 10 rows using pandas

# %%
df = pd.DataFrame(list_rows)
df.head(10)
# Out:
#                                                    0
# 0                                                 []
# 1                                  [Finishers:, 577]
# 2                                       [Male:, 414]
# 3                                     [Female:, 163]
# 4                                                 []
# 5  [1, 814, \r\n\r\n                    JARED WIL...
# 6  [2, 573, \r\n\r\n                    NATHAN A ...
# 7  [3, 687, \r\n\r\n                    FRANCISCO...
# 8  [4, 623, \r\n\r\n                    PAUL MORR...
# 9  [5, 569, \r\n\r\n                    DEREK G O...

# %% [markdown]
# Data manipulation and cleaning

# %% [markdown]
# The dataframe is not in the format we want to clean it up. you shold split the "0" column into multiple columns aat the comma positio.
# this is accomplished by using the st. split()method

# %%
#copy the old dataframe df and specify by starting at column 0 and pass #and pass to split function to split the text acros,
df1 = df[0].str.split(',',expand=True)# expand=True is extra argument
df1.head(10)
# Out:
#              0      1                                                  2  \
# 0           []   None                                               None
# 1  [Finishers:   577]                                               None
# 2       [Male:   414]                                               None
# 3     [Female:   163]                                               None
# 4           []   None                                               None
# 5           [1    814   \r\n\r\n                    JARED WILSON\r\n\...
# 6           [2    573   \r\n\r\n                    NATHAN A SUSTERSI...
# 7           [3    687   \r\n\r\n                    FRANCISCO MAYA\r\...
# 8           [4    623   \r\n\r\n                    PAUL MORROW\r\n\r...
# 9           [5    569   \r\n\r\n                    DEREK G OSBORNE\r...
#
#       3           4     5       6      7       8  \
# 0  None        None  None    None   None    None
# 1  None        None  None    None   None    None
# ...

# %% [markdown]
# Hmmp! This looks much better. but there is still work to do. this dataframe has unwanted square brackets sorruunding each row.
# you can use the strip() method to remove the opening square bracket on column "0"

# %%
df1[0] = df1[0].str.strip('[')
df1.head(10)
# Out:
#             0      1                                                  2     3  \
# 0           ]   None                                               None  None
# 1  Finishers:   577]                                               None  None
# 2       Male:   414]                                               None  None
# 3     Female:   163]                                               None  None
# 4           ]   None                                               None  None
# 5           1    814   \r\n\r\n                    JARED WILSON\r\n\...     M
# 6           2    573   \r\n\r\n                    NATHAN A SUSTERSI...     M
# 7           3    687   \r\n\r\n                    FRANCISCO MAYA\r\...     M
# 8           4    623   \r\n\r\n                    PAUL MORROW\r\n\r...     M
# 9           5    569   \r\n\r\n                    DEREK G OSBORNE\r...     M
#
#             4     5       6      7       8  \
# 0        None  None    None   None    None
# ...

# %% [markdown]
# so the table is missing table headers. you can use the find_all() method to get the table headers

# %%
col_labels = soup.find_all('th')#i am looking for the headers from
#the website

# %%
col_labels
# Out:
# [<th>Place</th>,
#  <th>Bib</th>,
#  <th>Name</th>,
#  <th>Gender</th>,
#  <th>City</th>,
#  <th>State</th>,
#  <th>Chip Time</th>,
#  <th>Chip Pace</th>,
#  <th>Gun Time</th>,
#  <th>Team</th>]

# %% [markdown]
# Similar to table rows, you can use Beautiful soup to exreact text in between html tags for table headers.

# %%
all_headers = []#create an empty list so i can use it later
col_str = str(col_labels)#pass it to str function
cleantext2 = BeautifulSoup(col_str,"lxml").get_text()#use Beautifulsoup
all_headers.append(cleantext2)
print(all_headers)
# Out:
# ['[Place, Bib, Name, Gender, City, State, Chip Time, Chip Pace, Gun Time, Team]']

# %% [markdown]
# ['[place, bib, name, Gender, city state, chip time chip pace, gun time, team]']

# %% [markdown]
# then we can then convert the list of headers into a pandas dataframe

# %%
df2 = pd.DataFrame(all_headers) #dataframe #Ibrahim
df2.head()
# Out:
#                                                    0
# 0  [Place, Bib, Name, Gender, City, State, Chip T...

# %% [markdown]
# # similarly, you can split column "0" into multiple column at the comma positin for all rows

# %%
df3 = df2[0].str.split(',',expand=True)
df3.head()
# Out:
#         0     1      2        3      4       5           6           7  \
# 0  [Place   Bib   Name   Gender   City   State   Chip Time   Chip Pace
#
#            8       9
# 0   Gun Time   Team]

# %% [markdown]
# The two dataframes can be concatenated into one using the concat()method as illustrated below.

# %%
frames = [df3, df1]

df4 = pd.concat(frames)#creating a new dataframe 4 and then ask pandas to concatene both frame into 1 funtion dataframe
df4
# Out:
#               0      1                                                  2  \
# 0        [Place    Bib                                               Name
# 0             ]   None                                               None
# 1    Finishers:   577]                                               None
# 2         Male:   414]                                               None
# 3       Female:   163]                                               None
# ..          ...    ...                                                ...
# 577         573    273   \r\n\r\n                    RACHEL L VANEY\r\...
# 578         574    467   \r\n\r\n                    ROHIT B DSOUZA\r\...
# 579         575    471   \r\n\r\n                    CENITA D'SOUZA\r\...
# 580         576    338   \r\n\r\n                    PRANAVI APPANA\r\...
# 581         577    443   \r\n\r\n                    LIBBY B MITCHELL\...
#
#            3           4       5           6           7          8  \
# ...

# %% [markdown]
# Now,let's assign the first row to be the table header. we gonna use a index.iloc[]

# %%
df5 = df4.rename(columns=df4.iloc[0])
df5.head()
# Out:
#        [Place    Bib   Name   Gender   City   State   Chip Time   Chip Pace  \
# 0      [Place    Bib   Name   Gender   City   State   Chip Time   Chip Pace
# 0           ]   None   None     None   None    None        None        None
# 1  Finishers:   577]   None     None   None    None        None        None
# 2       Male:   414]   None     None   None    None        None        None
# 3     Female:   163]   None     None   None    None        None        None
#
#     Gun Time   Team]
# 0   Gun Time   Team]
# 0       None    None
# 1       None    None
# 2       None    None
# 3       None    None

# %% [markdown]
# at this point, the table is almost properly formatted. for analysis department to use, you can start by gettin an overview of the data.

# %%
df5.info()#gives you tad bit of  information about the structure of the table
#like what each column data type is? some
#column are object(i mean string)and the total no of columns we have
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 583 entries, 0 to 581
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   [Place      583 non-null    object
#  1    Bib        581 non-null    object
#  2    Name       578 non-null    object
#  3    Gender     578 non-null    object
#  4    City       578 non-null    object
#  5    State      578 non-null    object
#  6    Chip Time  578 non-null    object
#  7    Chip Pace  578 non-null    object
#  8    Gun Time   578 non-null    object
#  9    Team]      578 non-null    object
# dtypes: object(10)
# memory usage: 50.1+ KB

# %%
df5.shape
# Out:
# (583, 10)

# %%
df5.isnull().any()
# Out:
# [Place        False
#  Bib           True
#  Name          True
#  Gender        True
#  City          True
#  State         True
#  Chip Time     True
#  Chip Pace     True
#  Gun Time      True
#  Team]         True
# dtype: bool

# %%
df5.isnull().sum()  #check if there is a missing value
# Out:
# [Place        0
#  Bib          2
#  Name         5
#  Gender       5
#  City         5
#  State        5
#  Chip Time    5
#  Chip Pace    5
#  Gun Time     5
#  Team]        5
# dtype: int64

# %% [markdown]
# # i think maybe we can drop all the stupid rows with any missing values.

# %%
df5.isnull().sum().sum()#check if there is a missing value
# Out:
# 42

# %%
df6 = df5.dropna(axis=0, how='any')#axis=0 means drop only for the rows

# %% [markdown]
# Notice how the table header is replicated as the first row in df5.it can be drop using the following line code

# %%
df6.head()
# Out:
#    [Place   Bib                                               Name   Gender  \
# 0  [Place   Bib                                               Name   Gender
# 5       1   814   \r\n\r\n                    JARED WILSON\r\n\...        M
# 6       2   573   \r\n\r\n                    NATHAN A SUSTERSI...        M
# 7       3   687   \r\n\r\n                    FRANCISCO MAYA\r\...        M
# 8       4   623   \r\n\r\n                    PAUL MORROW\r\n\r...        M
#
#          City   State   Chip Time   Chip Pace   Gun Time  \
# 0        City   State   Chip Time   Chip Pace   Gun Time
# 5      TIGARD      OR       36:21        5:51      36:24
# 6    PORTLAND      OR       36:42        5:55      36:45
# 7    PORTLAND      OR       37:44        6:05      37:48
# 8   BEAVERTON      OR       38:34        6:13      38:37
#
#                                                Team]
# 0                                              Team]
# 5                                                  ]
# ...

# %% [markdown]
# notice how the table header is replicated as the first row in df5. it can be dropped using the following line code.

# %%
df7 = df6.drop(df6.index[0])
df7.head()
# Out:
#   [Place   Bib                                               Name  Gender  \
# 5      1   814   \r\n\r\n                    JARED WILSON\r\n\...       M
# 6      2   573   \r\n\r\n                    NATHAN A SUSTERSI...       M
# 7      3   687   \r\n\r\n                    FRANCISCO MAYA\r\...       M
# 8      4   623   \r\n\r\n                    PAUL MORROW\r\n\r...       M
# 9      5   569   \r\n\r\n                    DEREK G OSBORNE\r...       M
#
#          City  State  Chip Time  Chip Pace  Gun Time  \
# 5      TIGARD     OR      36:21       5:51     36:24
# 6    PORTLAND     OR      36:42       5:55     36:45
# 7    PORTLAND     OR      37:44       6:05     37:48
# 8   BEAVERTON     OR      38:34       6:13     38:37
# 9   HILLSBORO     OR      39:21       6:20     39:24
#
#                                                Team]
# 5                                                  ]
# 6   \n\r\n                            INTEL TEAM ...
# ...

# %% [markdown]
# you can perform more data cleaning by renaming the '[Place' and 'Team]' columns. Python is very picky about space.make sure you include space after the quotation mark in team]'.

# %%
df7.columns
# Out:
# Index(['Place', ' Bib', ' Name', ' Gender', ' City', ' State', ' Chip Time',
#        ' Chip Pace', ' Gun Time', ' Team]'],
#       dtype='object')

# %%
#let's remove some things like [place to place]
df7.rename(columns={'[Place': 'Place'},inplace=True)
df7.rename(columns={' Team]': 'Team'},inplace=True)
df7.head()
# Out:
#   Place   Bib                                               Name  Gender  \
# 5     1   814   \r\n\r\n                    JARED WILSON\r\n\...       M
# 6     2   573   \r\n\r\n                    NATHAN A SUSTERSI...       M
# 7     3   687   \r\n\r\n                    FRANCISCO MAYA\r\...       M
# 8     4   623   \r\n\r\n                    PAUL MORROW\r\n\r...       M
# 9     5   569   \r\n\r\n                    DEREK G OSBORNE\r...       M
#
#          City  State  Chip Time  Chip Pace  Gun Time  \
# 5      TIGARD     OR      36:21       5:51     36:24
# 6    PORTLAND     OR      36:42       5:55     36:45
# 7    PORTLAND     OR      37:44       6:05     37:48
# 8   BEAVERTON     OR      38:34       6:13     38:37
# 9   HILLSBORO     OR      39:21       6:20     39:24
#
#                                                 Team
# 5                                                  ]
# 6   \n\r\n                            INTEL TEAM ...
# ...

# %% [markdown]
# The final data cleaning step involves removing the closing brackets for cells in the "Team" column

# %%
df7['Team'] = df7['Team'].str.strip(']')
df7.head()
# Out:
#   Place   Bib                                               Name  Gender  \
# 5     1   814   \r\n\r\n                    JARED WILSON\r\n\...       M
# 6     2   573   \r\n\r\n                    NATHAN A SUSTERSI...       M
# 7     3   687   \r\n\r\n                    FRANCISCO MAYA\r\...       M
# 8     4   623   \r\n\r\n                    PAUL MORROW\r\n\r...       M
# 9     5   569   \r\n\r\n                    DEREK G OSBORNE\r...       M
#
#          City  State  Chip Time  Chip Pace  Gun Time  \
# 5      TIGARD     OR      36:21       5:51     36:24
# 6    PORTLAND     OR      36:42       5:55     36:45
# 7    PORTLAND     OR      37:44       6:05     37:48
# 8   BEAVERTON     OR      38:34       6:13     38:37
# 9   HILLSBORO     OR      39:21       6:20     39:24
#
#                                                 Team
# 5
# 6   \n\r\n                            INTEL TEAM ...
# 7
# 8
# 9   \n\r\n                            INTEL TEAM ...

# %%
df7['Team'] = df7['Team'].str.strip(']')
df7.head()
df7.to_excel('file.xlsx')

# %%
df7.to_excel('file.xlsx')
